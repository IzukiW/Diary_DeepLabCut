# %%
#準備
import numpy as np
import pandas as pd
import glob
import os

#change directory
directory_path=r"Z:\evaluation-results-pytorch\iteration-0\Cladonema_starved_crop_tentacle20Jun26-trainset90shuffle1"
os.chdir(directory_path)

# Get all .h5 files in the directory
h5_files = glob.glob("*.h5")

for h5_file in h5_files:
    # Load the .h5 file
    data = pd.read_hdf(h5_file)

    # Extract the filename without extension
    filename = os.path.splitext(os.path.basename(h5_file))[0]

    # Save to CSV
    csv_filename = f"{filename}.csv"
    data.to_csv(csv_filename, index=True)
    
    print(f"Converted {h5_file} to {csv_filename}")
# Out:
# Converted DLC_Resnet50_Cladonema_starved_crop_tentacle20Jun26shuffle1_snapshot_040.h5 to DLC_Resnet50_Cladonema_starved_crop_tentacle20Jun26shuffle1_snapshot_040.csv

# %%
df = pd.read_hdf('DLC_Resnet50_Cladonema_starved_crop_tentacle20Jun26shuffle1_snapshot_040.h5')
df
# Out:
# scorer                                            DLC_Resnet50_Cladonema_starved_crop_tentacle20Jun26shuffle1_snapshot_040  \
# individuals                                                                                                         animal
# bodyparts                                                                                                   manubrium_base
# coords                                                                                                                   x
# labeled-data DSC_3174_roi_trial2_crop img0025.png                                         192.063873
#                                       img0245.png                                         203.486374
#                                       img0272.png                                         234.525101
#                                       img0315.png                                         260.227600
#                                       img0422.png                                         247.186859
# ...                                                                                              ...
#              DSC_3191_roi_trial1_crop img1922.png                                                NaN
#                                       img1963.png                                                NaN
#                                       img2174.png                                                NaN
#                                       img2512.png                                                NaN
#                                       img2675.png                                                NaN
#
# scorer                                                                    \
# individuals
# bodyparts
# coords                                                      y likelihood
# labeled-data DSC_3174_roi_trial2_crop img0025.png  164.280823   0.573569
#                                       img0245.png  167.393616   0.491935
#                                       img0272.png  168.675461   0.588649
#                                       img0315.png  186.387283   0.236831
#                                       img0422.png  157.487503   0.744849
# ...                                                       ...        ...
#              DSC_3191_roi_trial1_crop img1922.png         NaN        NaN
#                                       img1963.png         NaN        NaN
#                                       img2174.png         NaN        NaN
#                                       img2512.png         NaN        NaN
#                                       img2675.png         NaN        NaN
#
# scorer                                                                     \
# individuals
# bodyparts                                               mouth
# coords                                                      x           y
# labeled-data DSC_3174_roi_trial2_crop img0025.png  201.156876  204.788376
#                                       img0245.png  211.957794  191.330490
#                                       img0272.png  212.951096  203.800858
#                                       img0315.png  214.677917  209.772964
#                                       img0422.png  216.429123  212.594788
# ...                                                       ...         ...
#              DSC_3191_roi_trial1_crop img1922.png         NaN         NaN
#                                       img1963.png         NaN         NaN
#                                       img2174.png         NaN         NaN
#                                       img2512.png         NaN         NaN
#                                       img2675.png         NaN         NaN
#
# scorer                                                                    \
# individuals
# bodyparts                                                           prey
# coords                                            likelihood           x
# labeled-data DSC_3174_roi_trial2_crop img0025.png   0.765519  388.914917
#                                       img0245.png   0.214237  303.015930
#                                       img0272.png   0.680698  319.707306
#                                       img0315.png   0.953467  314.672852
#                                       img0422.png   0.781274  266.827087
# ...                                                      ...         ...
#              DSC_3191_roi_trial1_crop img1922.png        NaN         NaN
#                                       img1963.png        NaN         NaN
#                                       img2174.png        NaN         NaN
#                                       img2512.png        NaN         NaN
#                                       img2675.png        NaN         NaN
#
# scorer                                                                    \
# individuals
# bodyparts
# coords                                                      y likelihood
# labeled-data DSC_3174_roi_trial2_crop img0025.png  266.535309   0.901534
#                                       img0245.png  199.484421   0.966713
#                                       img0272.png  228.675262   1.000000
#                                       img0315.png  259.325653   0.820432
#                                       img0422.png  199.727646   0.249869
# ...                                                       ...        ...
#              DSC_3191_roi_trial1_crop img1922.png         NaN        NaN
#                                       img1963.png         NaN        NaN
#                                       img2174.png         NaN        NaN
#                                       img2512.png         NaN        NaN
#                                       img2675.png         NaN        NaN
#
# scorer                                                             ...  \
# individuals                                                        ...
# bodyparts                                         tentacle_base_1  ...
# coords                                                          x  ...
# labeled-data DSC_3174_roi_trial2_crop img0025.png      179.205536  ...
#                                       img0245.png      182.225113  ...
#                                       img0272.png      190.364105  ...
#                                       img0315.png      194.579880  ...
#                                       img0422.png      201.689545  ...
# ...                                                           ...  ...
#              DSC_3191_roi_trial1_crop img1922.png             NaN  ...
#                                       img1963.png             NaN  ...
#                                       img2174.png             NaN  ...
#                                       img2512.png             NaN  ...
#                                       img2675.png             NaN  ...
#
# scorer                                                              \
# individuals
# bodyparts                                         tentacle_base_17
# coords                                                  likelihood
# labeled-data DSC_3174_roi_trial2_crop img0025.png         0.004621
#                                       img0245.png         0.004131
#                                       img0272.png         0.001703
#                                       img0315.png         0.002406
#                                       img0422.png         0.002717
# ...                                                            ...
#              DSC_3191_roi_trial1_crop img1922.png              NaN
#                                       img1963.png              NaN
#                                       img2174.png              NaN
#                                       img2512.png              NaN
#                                       img2675.png              NaN
#
# scorer                                                              \
# individuals
# bodyparts                                         tentacle_base_18
# coords                                                           x
# labeled-data DSC_3174_roi_trial2_crop img0025.png       387.978302
#                                       img0245.png       291.955811
#                                       img0272.png       291.546112
#                                       img0315.png       275.606903
#                                       img0422.png       260.412262
# ...                                                            ...
#              DSC_3191_roi_trial1_crop img1922.png              NaN
#                                       img1963.png              NaN
#                                       img2174.png              NaN
#                                       img2512.png              NaN
#                                       img2675.png              NaN
#
# scorer                                                                    \
# individuals
# bodyparts
# coords                                                      y likelihood
# labeled-data DSC_3174_roi_trial2_crop img0025.png  259.944946   0.004637
#                                       img0245.png  196.287064   0.004847
#                                       img0272.png  227.984924   0.004978
#                                       img0315.png  196.152435   0.004565
#                                       img0422.png  212.099457   0.004796
# ...                                                       ...        ...
#              DSC_3191_roi_trial1_crop img1922.png         NaN        NaN
#                                       img1963.png         NaN        NaN
#                                       img2174.png         NaN        NaN
#                                       img2512.png         NaN        NaN
#                                       img2675.png         NaN        NaN
#
# scorer                                                              \
# individuals
# bodyparts                                         tentacle_base_19
# coords                                                           x
# labeled-data DSC_3174_roi_trial2_crop img0025.png       371.851593
#                                       img0245.png       307.907562
#                                       img0272.png       300.134430
#                                       img0315.png       275.471069
#                                       img0422.png       164.460571
# ...                                                            ...
#              DSC_3191_roi_trial1_crop img1922.png              NaN
#                                       img1963.png              NaN
#                                       img2174.png              NaN
#                                       img2512.png              NaN
#                                       img2675.png              NaN
#
# scorer                                                                    \
# individuals
# bodyparts
# coords                                                      y likelihood
# labeled-data DSC_3174_roi_trial2_crop img0025.png  252.229645   0.004262
#                                       img0245.png  196.190536   0.004028
#                                       img0272.png  227.755524   0.003164
#                                       img0315.png  196.070435   0.003634
#                                       img0422.png  140.052750   0.005927
# ...                                                       ...        ...
#              DSC_3191_roi_trial1_crop img1922.png         NaN        NaN
#                                       img1963.png         NaN        NaN
#                                       img2174.png         NaN        NaN
#                                       img2512.png         NaN        NaN
#                                       img2675.png         NaN        NaN
#
# scorer                                                              \
# individuals
# bodyparts                                         tentacle_base_20
# coords                                                           x
# labeled-data DSC_3174_roi_trial2_crop img0025.png       371.844940
#                                       img0245.png       308.239868
#                                       img0272.png       292.092316
#                                       img0315.png       275.795258
#                                       img0422.png       260.179047
# ...                                                            ...
#              DSC_3191_roi_trial1_crop img1922.png              NaN
#                                       img1963.png              NaN
#                                       img2174.png              NaN
#                                       img2512.png              NaN
#                                       img2675.png              NaN
#
# scorer
# individuals
# bodyparts
# coords                                                      y likelihood
# labeled-data DSC_3174_roi_trial2_crop img0025.png  252.328735   0.004687
#                                       img0245.png  195.645874   0.007644
#                                       img0272.png  227.635132   0.003579
#                                       img0315.png  196.483490   0.003398
#                                       img0422.png  212.517288   0.003127
# ...                                                       ...        ...
#              DSC_3191_roi_trial1_crop img1922.png         NaN        NaN
#                                       img1963.png         NaN        NaN
#                                       img2174.png         NaN        NaN
#                                       img2512.png         NaN        NaN
#                                       img2675.png         NaN        NaN
#
# [380 rows x 69 columns]

# %% [markdown]
# excel版

# %%
import openpyxl

excel_name= 'Evaluate_error_new.xlsx'

# %%
#準備
import numpy as np
import pandas as pd
import glob
import os
import openpyxl

#change directory
directory_path=r"Z:\evaluation-results-pytorch\iteration-0\Cladonema_starved_crop_tentacle20Jun26-trainset90shuffle1"
os.chdir(directory_path)

# Get all .h5 files in the directory
h5_files = glob.glob("*.h5")

for h5_file in h5_files:
    # Load the .h5 file
    data = pd.read_hdf(h5_file)

    # Extract the filename without extension
    filename = os.path.splitext(os.path.basename(h5_file))[0]

    # Save to excel
    excel_name = f"{filename}.xlsx"
    data.to_excel(excel_name)
    
    print(f"Converted {h5_file} to {excel_name}")
# Out:
# Converted DLC_Resnet50_Cladonema_starved_crop_tentacle20Jun26shuffle1_snapshot_040.h5 to DLC_Resnet50_Cladonema_starved_crop_tentacle20Jun26shuffle1_snapshot_040.xlsx
